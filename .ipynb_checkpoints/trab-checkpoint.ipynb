# %% [markdown]
# # Laboratorio 1 - Análisis Exploratorio de Datos
# ### Indicadores Macroeconómicos Mundiales
#
# Grupo 7:
# - Ariel Espinoza (202373060-2)
# - Martin García (202373068-8)
# - Williams Ajata (202204067-k)
# - Catalina Yañez (202273010-2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.style.use('default')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ## 1. Carga y Contextualización del Dataset

# %%
df = pd.read_csv("world_bank_data_2025.csv")
df.head()

# %% [markdown]
# **Contexto del dataset**
# - Contiene indicadores macroeconómicos de diversos países a lo largo de varios años.
# - Fuente: Banco Mundial y otras fuentes internacionales.
# - Motivación:  Nos intereso este dataset ya que es parte de la vida real y permite realizar un análisis de como los países se enfrentan a crisis o crecimiento económico, de esta forma podemos relacionar las variables y concluir las posibles causantes de estas.

# %% [markdown]
# ## 2. Limpieza y Preparación de Datos

# %% [markdown]
# **Información inicial del dataset**

# %%
print(df.info())

# %% [markdown]
# **Valores faltantes**

# %%
null_info = pd.DataFrame({
    "Valores_Nulos": df.isnull().sum(),
    "Porcentaje_Nulos": (df.isnull().sum() / len(df)) * 100
})
null_info[null_info["Valores_Nulos"] > 0]

# %% [markdown]
# **Tratar los valores faltantes**

# %%
for col in df.columns:
    if df[col].dtype in ['int64', 'float64']:
        df[col] = df[col].fillna(df[col].median())
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# **Normalizar texto**

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].astype(str).str.strip().str.lower()

# %% [markdown]
# **Eliminar Duplicados**

# %%
df = df.drop_duplicates()

# %% [markdown]
# **Comprobar información general**

# %%
print(df.info())

# %% [markdown]
# **Comprobar Valores Nulos**

# %%
null_info = pd.DataFrame({
    "Valores_Nulos": df.isnull().sum(),
    "Porcentaje_Nulos": (df.isnull().sum() / len(df)) * 100
})
null_info[null_info["Valores_Nulos"] > 0]

# %% [markdown]
# **Comprobar de valores atípicos**

# %%
df[(df["Unemployment Rate (%)"] < 0) | (df["Unemployment Rate (%)"] > 50)]

# %% [markdown]
# ## 3. Análisis Exploratorio de Datos

# %% [markdown]
# **Identificar columnas numéricas y categóricas**

# %%
num_cols = df.select_dtypes(include=[np.number]).columns
cat_cols = df.select_dtypes(exclude=[np.number]).columns

print("Variables numéricas:", list(num_cols))
print("Variables categóricas:", list(cat_cols))

# %% [markdown]
# **Estadísticas de las numéricas**

# %%
df[num_cols].describe().T

# %% [markdown]
# **Resumen de variables categóricas**

# %%
for c in cat_cols:
    print(f"\n{c}:")
    print(df[c].value_counts().head(5))

# %% [markdown]
# **Identificación de outliers**

# %%
def detectar_outliers(col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5*IQR
    limite_superior = Q3 + 1.5*IQR
    outliers = df[(df[col] < limite_inferior) | (df[col] > limite_superior)][col]
    return outliers

for col in num_cols:
    outliers = detectar_outliers(col)
    print(f"{col}: {len(outliers)} outliers detectados")

# %% [markdown]
# **Boxplots**

# %%
df[num_cols].boxplot(figsize=(12,6))
plt.title("Boxplots - Variables numéricas")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
df[num_cols].boxplot()
plt.yscale("log")
plt.title("Boxplots con escala logarítmica")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Top 10 países por PIB promedio**

# %%
df.groupby("country_name")["GDP (Current USD)"].mean().sort_values(ascending=False).head(10)

# %% [markdown]
# **Top 10 países por crecimiento promedio**

# %%
df.groupby("country_name")["GDP Growth (% Annual)"].mean().sort_values(ascending=False).head(10)

# %% [markdown]
# ## 4. Visualizaciones

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
colors = ['#1f77b4','#ff7f0e','#2ca02c','#d62728','#9467bd','#8c564b']

# Evolución PIB mundial
yearly_gdp = df.groupby("year")["GDP (Current USD)"].mean()
axes[0,0].plot(yearly_gdp.index, yearly_gdp.values, marker="o", color=colors[0])
axes[0,0].set_title("Evolución del PIB Mundial Promedio", fontweight="bold")
axes[0,0].set_xlabel("Año")
axes[0,0].set_ylabel("PIB Promedio (USD)")
axes[0,0].grid(True, alpha=0.3)

# Top 10 PIB
top_10 = df.groupby("country_name")["GDP (Current USD)"].mean().nlargest(10)
axes[0,1].barh(top_10.index, top_10.values, color=colors[:10])
axes[0,1].set_title("Top 10 Países por PIB Promedio", fontweight="bold")
axes[0,1].set_xlabel("PIB Promedio (USD)")
axes[0,1].set_ylabel("Países")

# Relación PIB per cápita vs desempleo
sample_df = df.sample(min(1000,len(df)))
axes[1,0].scatter(sample_df["GDP per Capita (Current USD)"], sample_df["Unemployment Rate (%)"], alpha=0.6, color=colors[2])
axes[1,0].set_title("Relación PIB per Cápita vs Desempleo", fontweight="bold")
axes[1,0].set_xlabel("PIB per Cápita (USD)")
axes[1,0].set_ylabel("Tasa de Desempleo (%)")
axes[1,0].set_xscale("log")

# Distribución crecimiento económico
growth_data = df["GDP Growth (% Annual)"].dropna()
axes[1,1].hist(growth_data, bins=30, color=colors[3], edgecolor="black", alpha=0.7)
axes[1,1].set_title("Distribución del Crecimiento Económico", fontweight="bold")
axes[1,1].set_xlabel("Crecimiento del PIB (% Anual)")
axes[1,1].set_ylabel("Frecuencia")
axes[1,1].grid(True, alpha=0.3)

plt.suptitle("Análisis Exploratorio - Indicadores Macroeconómicos Mundiales", fontsize=16, fontweight="bold")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# **Matriz de correlación**

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
corr = df[numeric_cols].corr()

plt.figure(figsize=(10,8))
im = plt.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1)
plt.xticks(range(len(corr)), corr.columns, rotation=45, ha="right")
plt.yticks(range(len(corr)), corr.columns)
plt.colorbar(im, label="Coef. Correlación")
plt.title("Matriz de Correlación - Variables Económicas")
plt.show()

# %% [markdown]
# ## Gráficos evolución Mundial

# %%
world_growth = df.groupby("year")["GDP Growth (% Annual)"].mean()
world_unemployment = df.groupby("year")["Unemployment Rate (%)"].mean()
world_inflation = df.groupby("year")["Inflation (CPI %)"].mean()
fig, axes = plt.subplots(3, 1, figsize=(12, 15), sharex=True)

# Crecimiento económico
axes[0].plot(world_growth.index, world_growth.values, marker="o", color="green", label="Crecimiento económico mundial")
axes[0].set_title("Evolución del crecimiento económico mundial (% promedio anual)", fontweight="bold")
axes[0].set_ylabel("GDP Growth (%)")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Desempleo
axes[1].plot(world_unemployment.index, world_unemployment.values, marker="o", color="red", label="Desempleo mundial")
axes[1].set_title("Evolución del desempleo mundial (% promedio anual)", fontweight="bold")
axes[1].set_ylabel("Unemployment Rate (%)")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# Inflación
axes[2].plot(world_inflation.index, world_inflation.values, marker="o", color="blue", label="Inflación mundial")
axes[2].set_title("Evolución de la Inflación Mundial (CPI %)", fontweight="bold")
axes[2].set_xlabel("Año")
axes[2].set_ylabel("Inflación (CPI %)")
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Selección de Variables
# - **Principales**: `Unemployment Rate (%)`, `GDP Growth (% Annual)`
# - **Secundarias**: `Inflation (CPI %)`, `GDP (Current USD)`
#
# **Justificación**:
# - PIB y crecimiento son indicadores centrales del desempeño económico.
# - Inflación y desempleo son críticos en política económica.
# - Existen correlaciones interesantes entre ellas.

# %% [markdown]
# Nota: Idea confirmada por ChatGPT: en base a nuestro trabajo, considerarias que el gdp(current usd), y gdp growth% anual como principales, y la inflation CPI% y Unemployment rate% como secundarias es una factible seleccion de variables para poder hondar en nuestra pregunta de investigacion?

# %% [markdown]
# ## 6. Pregunta de Investigación
# Analizando los datos, nos dimos cuenta de que los paises más desarrolados tienen in PIB mucho más elevado que el de aquellos que no, en especial aquellas que pueden ser consideradas potencias mundiales, cómo China y EE.UU. Además, el crecimiento del PIB en el mundo empezó a crecer en gran manera en 2020, lo que justamente coincide con la pandemia, lo que nos deja con la idea de que algunos paises pudieron aprovechar muy bien la situación para poder crecer y desarrollarse durante este periodo, teninendo como consecuencia, que su PIB aumente. Sin embargo, siguen habiendo paises que se quedaron algo atras en comparación a otros, dando como resultado que tengan una tasa de desempleo más alta, ya que no supieron adaptarse tan bien como otros, evidenciando que, mientras más alta la tasa de crecimiento del PIB, la empleabilidad aumenta. Aunque, hay que destacar que, aunque algunos paises tengan un PIB muy alto, este no tiene una tasa de crecimiento tan alta como otros paises que tienen menos PIB.
#
# Con esto en mente, no planteamos la siguiente pregunta de investigación:
#
# **¿La tasa de crecimiento del PIB influye mucho más que la inflación y el PIB actual de un país, en su tasa de desempleo?**
#
# Hipotesis de la pregunta planteada:
#
# **La tasa de crecimiento sí influye más que el resto de variables en cuanto a la tasa de desempleo, siendo el PIB actual una forma de verificarlo y la inflación un factor que restrasaría este crecimiento.**

# %% [markdown]
# # Laboratorio 2 - Simulación e Inferencia

# %% [markdown]
# ## 1. Estimación puntual

# %% [markdown]
# **Necesario ejecutar el código del laboratorio anteriror para evitar problemas**

# %%
pip install scipy scikit-learn

# %%
import scipy.stats as stats
from scipy.stats import t, norm
import warnings
warnings.filterwarnings('ignore')

def calcular_estimadores_puntuales(data, variable_name):
    data_clean = data.dropna()
    n = len(data_clean)
    
    if n == 0:
        return None

    estimadores = {
        'n': n,
        'media_muestral': np.mean(data_clean),
        'mediana': np.median(data_clean),
        'varianza_muestral': np.var(data_clean, ddof=1),
        'desviacion_estandar': np.std(data_clean, ddof=1),
        'error_estandar_media': np.std(data_clean, ddof=1) / np.sqrt(n),
        'coef_variacion': (np.std(data_clean, ddof=1) / np.mean(data_clean)) * 100 if np.mean(data_clean) != 0 else np.nan,
        'minimo': np.min(data_clean),
        'maximo': np.max(data_clean),
        'q1': np.percentile(data_clean, 25),
        'q3': np.percentile(data_clean, 75),
        'rango_intercuartil': np.percentile(data_clean, 75) - np.percentile(data_clean, 25),
        'asimetria': stats.skew(data_clean),
        'curtosis': stats.kurtosis(data_clean)
    }
    
    # Intervalo de confianza 95% para la media
    alpha = 0.05
    t_critical = t.ppf(1 - alpha/2, df=n-1)
    margin_error = t_critical * estimadores['error_estandar_media']
    
    estimadores['ic_95_inferior'] = estimadores['media_muestral'] - margin_error
    estimadores['ic_95_superior'] = estimadores['media_muestral'] + margin_error
    estimadores['margen_error'] = margin_error
    
    return estimadores

variables_principales = [
    'GDP Growth (% Annual)',
    'Inflation (CPI %)', 
    'GDP (Current USD)',
    'Unemployment Rate (%)'
]

print("1. Variables Seleccionadas para Estimación")
print()
print("Basándome en nuestra pregunta de investigación:")
print("¿La tasa de crecimiento del PIB influye mucho más que la inflación y el PIB actual de un país, en su tasa de desempleo?")
print()
print("Las variables seleccionadas para estimación puntual son:")
for i, var in enumerate(variables_principales, 1):
    tipo = 'dependiente' if 'Unemployment' in var else 'independiente'
    print(f"{i}. {var}: Variable {tipo}")
    
print()

resultados_estimacion = {}

print("2. Estimadores Puntuales por Variable")
print()

for variable in variables_principales:
    print(f"2.{variables_principales.index(variable) + 1}. {variable}")
    print()
    
    estimadores = calcular_estimadores_puntuales(df[variable], variable)
    resultados_estimacion[variable] = estimadores
    
    if estimadores is not None:
        print(f"Estadísticos básicos:")
        print(f"- Tamaño de muestra (n): {estimadores['n']:,}")
        print(f"- Media muestral (μ̂): {estimadores['media_muestral']:.6f}")
        print(f"- Mediana: {estimadores['mediana']:.6f}")
        print(f"- Mínimo: {estimadores['minimo']:.4f}")
        print(f"- Máximo: {estimadores['maximo']:.4f}")
        print()
        
        print(f"Estimadores de dispersión:")
        print(f"- Varianza muestral (s²): {estimadores['varianza_muestral']:.6f}")
        print(f"- Desviación estándar (s): {estimadores['desviacion_estandar']:.6f}")
        print(f"- Error estándar de la media: {estimadores['error_estandar_media']:.6f}")
        print(f"- Coeficiente de variación: {estimadores['coef_variacion']:.2f}%")
        print(f"- Rango intercuartílico: {estimadores['rango_intercuartil']:.4f}")
        print()
        
        print(f"Estimadores de forma:")
        print(f"- Asimetría: {estimadores['asimetria']:.4f}")
        print(f"- Curtosis: {estimadores['curtosis']:.4f}")
        print()
        
        print(f"Intervalo de confianza 95% para la media:")
        print(f"- IC 95%: [{estimadores['ic_95_inferior']:.6f}, {estimadores['ic_95_superior']:.6f}]")
        print(f"- Margen de error: ±{estimadores['margen_error']:.6f}")
        print()
        
        print("Interpretación económica:")
        if 'GDP Growth' in variable:
            print("- La media muestral representa el crecimiento económico promedio de los países en la muestra")
            print("- Valores positivos indican expansión económica, negativos indican contracción")
            if estimadores['media_muestral'] > 0:
                print(f"- El crecimiento promedio de {estimadores['media_muestral']:.2f}% sugiere expansión económica general")
            else:
                print(f"- El crecimiento promedio de {estimadores['media_muestral']:.2f}% sugiere contracción económica")
        elif 'Inflation' in variable:
            print("- La media muestral representa la tasa de inflación promedio")
            print("- Valores entre 2-3% se consideran saludables para la economía")
            if 2 <= estimadores['media_muestral'] <= 3:
                print("- La inflación promedio está en el rango considerado saludable")
            elif estimadores['media_muestral'] > 3:
                print("- La inflación promedio está por encima del rango saludable")
            else:
                print("- La inflación promedio está por debajo del rango típico")
        elif 'GDP (Current USD)' in variable:
            print("- La media muestral representa el tamaño económico promedio de los países")
            print("- Indica la escala económica de los países en la muestra")
            print(f"- PIB promedio: ${estimadores['media_muestral']:,.0f}")
        elif 'Unemployment' in variable:
            print("- La media muestral representa la tasa de desempleo promedio")
            print("- Tasas menores a 5% generalmente indican mercados laborales saludables")
            if estimadores['media_muestral'] < 5:
                print("- ✓ La tasa de desempleo promedio sugiere mercados laborales relativamente saludables")
            else:
                print("- La tasa de desempleo promedio sugiere posibles tensiones en el mercado laboral")
        
        print()
        
        print("-" * 60)
        
        print()
    else:
        print("No hay datos suficientes para calcular estimadores.")
        
        print()

print("3. Tabla Comparativa de Estimadores Puntuales")

print()

comparison_data = []
for variable in variables_principales:
    if resultados_estimacion[variable] is not None:
        est = resultados_estimacion[variable]
        comparison_data.append({
            'Variable': variable.replace(' (%)', '').replace(' (Current USD)', ''),
            'n': f"{est['n']:,}",
            'Media': f"{est['media_muestral']:.4f}",
            'Mediana': f"{est['mediana']:.4f}",
            'Desv.Std': f"{est['desviacion_estandar']:.4f}",
            'Error Std': f"{est['error_estandar_media']:.6f}",
            'CV (%)': f"{est['coef_variacion']:.2f}",
            'IC 95%': f"[{est['ic_95_inferior']:.3f}, {est['ic_95_superior']:.3f}]"
        })

if comparison_data:
    comparison_df = pd.DataFrame(comparison_data)
    print("Resumen de estimadores puntuales:")
    
    print()
    
    print(comparison_df.to_string(index=False))
    
    print()
else:
    print("No se pudieron calcular estimadores para las variables.")

print("4. Validación de Supuestos Estadísticos")
print()

def test_normalidad_simple(data, alpha=0.05):
    """Test de normalidad apropiado según el tamaño de muestra"""
    data_clean = data.dropna()
    n = len(data_clean)
    
    if n < 3:
        return None
    
    try:
        if n > 5000:
            statistic, p_value = stats.kstest(data_clean, 'norm', 
                                            args=(np.mean(data_clean), np.std(data_clean)))
            test_name = "Kolmogorov-Smirnov"
        else:
            statistic, p_value = stats.shapiro(data_clean)
            test_name = "Shapiro-Wilk"
        
        return {
            'test': test_name,
            'statistic': statistic,
            'p_value': p_value,
            'es_normal': p_value > alpha,
            'n': n
        }
    except Exception as e:
        return None

print("Test de Normalidad")

print()

print("Evaluamos si las variables siguen distribución normal, lo cual valida")
print("el uso de estimadores basados en la distribución normal y los intervalos de confianza.")

print()

for variable in variables_principales:
    if resultados_estimacion[variable] is not None:
        test_result = test_normalidad_simple(df[variable])
        if test_result is not None:
            print(f"{variable}:")
            print(f"- Test utilizado: {test_result['test']} (n = {test_result['n']:,})")
            print(f"- Estadístico: {test_result['statistic']:.6f}")
            print(f"- p-valor: {test_result['p_value']:.6f}")
            print(f"- ¿Distribución normal?: {'SÍ' if test_result['es_normal'] else 'NO'} (α = 0.05)")
            
            if test_result['es_normal']:
                print("- Los estimadores basados en normalidad son apropiados")
                print("- Los intervalos de confianza son válidos")
            else:
                print("- Considerar estimadores robustos o transformaciones de datos")
                print("- Los intervalos de confianza pueden ser aproximados (Teorema Central del Límite)")
            
            print()
        else:
            print(f"{variable}: No se pudo realizar el test de normalidad")
            
            print()

print("5. Propiedades de los Estimadores Implementados")

print()

print("Media Muestral (X̄)")
print("- Insesgadez: E[X̄] = μ (estimador insesgado del parámetro poblacional)")
print("- Consistencia: Converge al parámetro poblacional cuando n → ∞")
print("- Eficiencia: Varianza mínima entre estimadores lineales insesgados (BLUE)")
print("- Normalidad asintótica: Distribución aproximadamente normal para muestras grandes")
print()

print("Varianza Muestral (s²)")
print("- Insesgadez: E[s²] = σ² (con corrección de Bessel, dividiendo por n-1)")
print("- Consistencia: Converge a la varianza poblacional")
print("- Eficiencia: Estimador de varianza mínima para distribuciones normales")

print()

print("Error Estándar de la Media")
print("- Utilidad: Mide la precisión de la estimación de la media")
print("- Interpretación: Menor error estándar indica mayor precisión en la estimación")
print("- Relación: SE(X̄) = s/√n, disminuye con el tamaño de muestra")

print()

print("Intervalos de Confianza")
print("- Interpretación: Con 95% de confianza, el parámetro poblacional está en el intervalo")
print("- Construcción: X̄ ± t₀.₀₂₅ × SE(X̄)")
print("- Validez: Requiere normalidad o muestras grandes (Teorema Central del Límite)")

print()

print("6. Conclusiones de la Estimación Puntual")

print()

print("Estimadores Implementados")
print("Se calcularon estimadores puntuales insesgados y eficientes para las variables macroeconómicas clave de nuestra investigación. Cada estimador proporciona información específica sobre los parámetros poblacionales de interés.")

print()

print("Validez Estadística")
print("Los estimadores implementados cumplen con las propiedades estadísticas deseables:")
print("- Insesgadez: Todos los estimadores son centrados en sus parámetros poblacionales")
print("- Eficiencia: Se utilizaron estimadores de varianza mínima")
print("- Consistencia: Los estimadores convergen a los parámetros verdaderos")

print()

print("Relevancia Económica")
print("Los estimadores proporcionan información valiosa sobre:")
print("- Tendencias centrales de las variables macroeconómicas en la muestra")
print("- Variabilidad y dispersión de cada indicador económico")
print("- Precisión de las estimaciones mediante errores estándar e intervalos de confianza")
print("- Características distribucionales como asimetría y curtosis")
print()

print("Implicaciones para la Investigación")
print("Los resultados de la estimación puntual proporcionan:")
print("- Base estadística sólida para caracterizar las variables de interés")
print("- Información cuantitativa sobre los parámetros poblacionales")
print("- Fundamento metodológico para análisis posteriores")
print("- Evidencia empírica sobre las características de los datos macroeconómicos")

print()

print("Limitaciones y Consideraciones")
print("- Los estimadores describen características muestrales que se generalizan a la población")
print("- La normalidad de algunas variables puede no cumplirse completamente")
print("- Los intervalos de confianza son aproximados cuando no se cumple normalidad")
print("- Se requiere análisis adicional para establecer relaciones causales entre variables")

print()

print("Esta implementación de estimación puntual proporciona una caracterización estadística completa de las variables macroeconómicas, estableciendo las bases para análisis econométricos posteriores y la evaluación de la hipótesis de investigación.")

# %% [markdown]
# ## 2. Métodos de remuestreo: Bootstrap

# %% [markdown]
# **1**
#
# El método Bootstrap nos permite, a base de realizar varios análisis con los datos disponibles, predecir lo que va a suceder al repetir el mismo experimento varias veces.
#
# Este fue inventado por Bradley Efron en 1979, cuyo nombre proviene de la frase to pull oneself up by one’s bootstrap, la cual representa la capacidad de poder salir adelante por los medios propios. Su motivación fue la de evitar que los resultados fueran alterados por fuertes supuestos, pudiendo así generar resultados más precisos con las muestras disponibles, provocando que sea muy versátil e importante en la estadística moderna.

# %% [markdown]
# **2**
#
# El método consiste en los siguientes pasos:
#
# - Contar el número de muestras analizadas y analizar alguna de las medidas estadísticas (media, promedio, moda, entre otras)
#
# - Crear una nueva colección de muestras con el mismo número de muestras que las originales, pudiendo seleccionar varias veces la misma muestra
#
# - Analizar la medida estadística realizada en la original y volver a hacerlo con la nueva colección
#
# - Repetir estos dos últimos pasos muchas veces
#
# - Crear un histograma que permita analizar la varianza, sesgo e intervalo de confianza, simulando así que se haya repetido el mismo experimento varias veces

# %% [markdown]
# **3**

# %%
from scipy.stats import gaussian_kde

def bootstrap_economico(data, statistic_func, n_bootstrap=3000, alpha=0.05, use_log=False):
    n = len(data)
    bootstrap_stats = []
    
    if use_log:
        data = np.log(data[data > 0])
        if len(data) == 0:
            return None
    
    original_stat = statistic_func(data)
    
    for i in range(n_bootstrap):
        bootstrap_sample = np.random.choice(data, size=n, replace=True)
        stat = statistic_func(bootstrap_sample)
        bootstrap_stats.append(stat)
    
    bootstrap_stats = np.array(bootstrap_stats)
    
    bias = np.mean(bootstrap_stats) - original_stat
    std_error = np.std(bootstrap_stats, ddof=1)
    
    lower_percentile = np.percentile(bootstrap_stats, (alpha/2)*100)
    upper_percentile = np.percentile(bootstrap_stats, (1-alpha/2)*100)
    
    z_critical = norm.ppf(1 - alpha/2)
    lower_normal = original_stat - z_critical * std_error
    upper_normal = original_stat + z_critical * std_error
    
    return {
        'original': original_stat,
        'bootstrap_mean': np.mean(bootstrap_stats),
        'bias': bias,
        'std_error': std_error,
        'ci_percentil': (lower_percentile, upper_percentile),
        'ci_normal': (lower_normal, upper_normal),
        'bootstrap_distribution': bootstrap_stats,
        'use_log': use_log
    }

print("Aplicación a Variables Económicas Clave:")

print()

variables_bootstrap = {
    'GDP Growth (% Annual)': {'desc': 'Crecimiento Económico', 'use_log': False},
    'Unemployment Rate (%)': {'desc': 'Tasa de Desempleo', 'use_log': False}, 
    'Inflation (CPI %)': {'desc': 'Tasa de Inflación', 'use_log': False},
    'GDP (Current USD)': {'desc': 'PIB Total (log)', 'use_log': True}
}

resultados_bootstrap = {}

for variable, config in variables_bootstrap.items():
    descripcion = config['desc']
    use_log = config['use_log']
    
    print(f"{descripcion} ({variable})")
    if use_log:
        print("NOTA: Usando transformación logarítmica para manejar la escala del PIB")
    
    data_clean = df[variable].dropna()
    
    if use_log:
        data_clean = data_clean[data_clean > 0]
        if len(data_clean) == 0:
            print(f"- No hay datos válidos para {variable} (valores positivos requeridos para log)")
            continue
    
    if len(data_clean) > 0:
        resultado = bootstrap_economico(data_clean, np.mean, n_bootstrap=1000, use_log=use_log)
        
        if resultado is not None:
            resultados_bootstrap[variable] = resultado
            
            if use_log:
                original_exp = np.exp(resultado['original'])
                bootstrap_mean_exp = np.exp(resultado['bootstrap_mean'])
                ci_lower_exp = np.exp(resultado['ci_percentil'][0])
                ci_upper_exp = np.exp(resultado['ci_percentil'][1])
                
                print(f"- Media original (escala original): ${original_exp:,.2f}")
                print(f"- Media bootstrap (escala original): ${bootstrap_mean_exp:,.2f}")
                print(f"- Sesgo (escala log): {resultado['bias']:.6f}")
                print(f"- Error estándar bootstrap (escala log): {resultado['std_error']:.4f}")
                print(f"- IC 95% percentil (escala original): [${ci_lower_exp:,.2f}, ${ci_upper_exp:,.2f}]")
            else:
                print(f"- Media original: {resultado['original']:.4f}")
                print(f"- Media bootstrap: {resultado['bootstrap_mean']:.4f}")
                print(f"- Sesgo estimado: {resultado['bias']:.4f}")
                print(f"- Error estándar bootstrap: {resultado['std_error']:.4f}")
                print(f"- IC 95% percentil: [{resultado['ci_percentil'][0]:.4f}, {resultado['ci_percentil'][1]:.4f}]")
            print()
    else:
        print(f"- No hay datos suficientes para {variable}")
        print()

# %% [markdown]
# **4**

# %%
resumen_data = []
for variable, config in variables_bootstrap.items():
    if variable in resultados_bootstrap:
        result = resultados_bootstrap[variable]
        use_log = config['use_log']
        
        if use_log:
            media_original = f"${np.exp(result['original']):,.2f}"
            media_bootstrap = f"${np.exp(result['bootstrap_mean']):,.2f}"
            sesgo = f"{result['bias']:.6f}"
            ic_text = f"[${np.exp(result['ci_percentil'][0]):,.2f}, ${np.exp(result['ci_percentil'][1]):,.2f}]"
        else:
            media_original = f"{result['original']:.4f}"
            media_bootstrap = f"{result['bootstrap_mean']:.4f}"
            sesgo = f"{result['bias']:.4f}"
            ic_text = f"[{result['ci_percentil'][0]:.3f}, {result['ci_percentil'][1]:.3f}]"
        
        resumen_data.append({
            'Indicador Económico': config['desc'],
            'Media Original': media_original,
            'Media Bootstrap': media_bootstrap,
            'Sesgo': sesgo,
            'Error Estándar': f"{result['std_error']:.4f}",
            'IC Percentil 95%': ic_text
        })

resumen_df = pd.DataFrame(resumen_data)
print(resumen_df.to_string(index=False))

print()

fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.ravel()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

for idx, (variable, config) in enumerate(variables_bootstrap.items()):
    if variable in resultados_bootstrap:
        result = resultados_bootstrap[variable]
        bootstrap_dist = result['bootstrap_distribution']
        use_log = config['use_log']
        descripcion = config['desc']
        
        if use_log:
            bootstrap_dist_exp = np.exp(bootstrap_dist)
            original_exp = np.exp(result['original'])
            bootstrap_mean_exp = np.exp(result['bootstrap_mean'])
            ci_lower_exp = np.exp(result['ci_percentil'][0])
            ci_upper_exp = np.exp(result['ci_percentil'][1])
            
            plot_data = bootstrap_dist_exp
            original_val = original_exp
            bootstrap_mean_val = bootstrap_mean_exp
            ci_lower = ci_lower_exp
            ci_upper = ci_upper_exp
            
            xlabel = 'PIB (USD)'
            original_label = f'Media original: ${original_val:,.2f}'
            bootstrap_label = f'Media bootstrap: ${bootstrap_mean_val:,.2f}'
        else:
            plot_data = bootstrap_dist
            original_val = result['original']
            bootstrap_mean_val = result['bootstrap_mean']
            ci_lower = result['ci_percentil'][0]
            ci_upper = result['ci_percentil'][1]
            
            xlabel = 'Valor del Estadístico'
            original_label = f'Media original: {original_val:.3f}'
            bootstrap_label = f'Media bootstrap: {bootstrap_mean_val:.3f}'
        
        n, bins, patches = axes[idx].hist(plot_data, bins=30, alpha=0.7, 
                                        color=colors[idx], edgecolor='black', 
                                        density=True)
        
        axes[idx].axvline(original_val, color='red', linestyle='--', 
                         linewidth=3, label=original_label)
        axes[idx].axvline(bootstrap_mean_val, color='blue', linestyle='--',
                         linewidth=2, label=bootstrap_label)

        axes[idx].axvline(ci_lower, color='green', linestyle=':', 
                         linewidth=2, alpha=0.8, label='Límites IC 95%')
        axes[idx].axvline(ci_upper, color='green', linestyle=':', 
                         linewidth=2, alpha=0.8)
        
        axes[idx].axvspan(ci_lower, ci_upper, 
                         alpha=0.2, color='green', label='IC 95%')
        
        kde = gaussian_kde(plot_data)
        x_vals = np.linspace(bins[0], bins[-1], 100)
        axes[idx].plot(x_vals, kde(x_vals), 'black', linewidth=1.5, label='Densidad')
        
        axes[idx].set_title(f'{descripcion}', fontweight='bold', fontsize=12)
        axes[idx].set_xlabel(xlabel, fontweight='bold')
        axes[idx].set_ylabel('Densidad de Probabilidad', fontweight='bold')
        axes[idx].legend(fontsize=8)
        axes[idx].grid(True, alpha=0.3)
        
        if use_log:
            textstr = f'Sesgo (log): {result["bias"]:.4f}\nError std (log): {result["std_error"]:.4f}'
        else:
            textstr = f'Sesgo: {result["bias"]:.4f}\nError std: {result["std_error"]:.4f}'
        
        props = dict(boxstyle='round', facecolor='wheat', alpha=0.8)
        axes[idx].text(0.02, 0.98, textstr, transform=axes[idx].transAxes, fontsize=8,
                      verticalalignment='top', bbox=props)

plt.suptitle('Distribuciones Bootstrap - Variables de hipótesis de investigación\n', 
             fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# **5**

# %% [markdown]
# Analizando los datos, podemos concluir que son bastante similares entre sí, lo que confirma que ambos métodos son igual de válidos. Sin embargo, el bootstrapping es más confiable en este caso, ya que, este permite que la inferencia sea más creíble al analizar los distintos países y sus economías. Además, los resultados entregados por este método son más apegados a la realidad, simulando correctamente lo que pasaría si se repitiera la recolección de datos varias veces. El único caso donde la estimación clásica tiene ventaja es cuando los supuestos son totalmente acertados, permitiendo que el proceso sea más rápido en comparación con la estimación mediante bootstrap.
#
# **¿Existen diferencias relevantes?**
# No existen diferencias relevantes entre los resultados obtenidos en estimación puntual y Bootstrap , estas difieren en menos de  0.01 % en las medias y coincidencia en los intervalos de confianza.
# Esto sugiere que los estimadores son insesgados, consistentes y eficientes, incluso bajo violaciones de normalidad como vimos en el estimador puntual.
# La única diferencia fue en la Inflación donde el IC bootstrap es ligeramente más amplio debido a la asimetría positiva de su distribución, además de comfirmar el comportamiento volátil entre países.
#
# **¿Qué ventajas aporta el bootstrap en el contexto de su análisis y qué limitaciones pueden identificarse?**
# No depende de supuestos de normalidad, el bootstrap ofrece IC válidos sin asumir distribución normal, en nuestro caso al realizar test de Shapiro-Wilk rechazo normalidad.
# Evalúa el sesgo empírico al poder cuatificar estimadores puntuales tienden a sobre- o sub-estimar el valor real.
# Limitaciones:
# Alta demanda computacional al tener que repetir la muestra muchas veces.
# El bootstrap repite el sesgo si la muestra original no representa bien la población, generando dependencia.
#
# Por lo que en nuestro caso, fue una herramienta valiosa al comprobar que los estimadores son insesgados, consistentes y eficientes.

# %% [markdown]
# # Laboratorio 3

# %% [markdown]
# ## 1. Analisis del IC

# %%
conf = 0.937
alpha = 1 - conf
lower_p = 100 * (alpha / 2)
upper_p = 100 * (1 - alpha / 2)

resultados_ic = {}

for var, result in resultados_bootstrap.items():
    boot_dist = np.array(result["bootstrap_distribution"])
    
    # Media y percentiles para IC (varianza desconocida)
    mean_boot = np.mean(boot_dist)
    ci_lower, ci_upper = np.percentile(boot_dist, [lower_p, upper_p])
    ic_width = ci_upper - ci_lower  # mide la incertidumbre (ancho del IC)
    
    resultados_ic[var] = {
        "mean": mean_boot,
        "ci_lower": ci_lower,
        "ci_upper": ci_upper,
        "ic_width": ic_width
    }
    
    print(f"{var}: media = {mean_boot:.3f}, IC[{conf*100:.1f}%] = [{ci_lower:.3f}, {ci_upper:.3f}], ancho = {ic_width:.3f}")

fig, axs = plt.subplots(len(resultados_bootstrap), 1, figsize=(9, 10))

for ax, (var, result) in zip(axs, resultados_bootstrap.items()):
    boot_dist = np.array(result["bootstrap_distribution"])
    
    stats = resultados_ic[var]
    
    ax.hist(boot_dist, bins=40, alpha=0.6, color='skyblue', density=True, edgecolor='white')
    
    ax.axvline(stats["ci_lower"], color='red', linestyle='--', linewidth=2, label=f'Límite inf = {stats["ci_lower"]:.2f}')
    ax.axvline(stats["ci_upper"], color='red', linestyle='--', linewidth=2, label=f'Límite sup = {stats["ci_upper"]:.2f}')
    
    ax.axvline(stats["mean"], color='green', linestyle='-', linewidth=2, label=f'Media = {stats["mean"]:.2f}')
    
    ax.set_title(f"Distribución Bootstrap — {var}\nAncho del IC = {stats['ic_width']:.3f}")
    ax.set_xlabel("Valor del estadístico")
    ax.set_ylabel("Densidad")
    ax.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# Analizando los resultados, se puede ver que el intervalo es bastante grande, por lo que su incertidumbre también lo es, si fuera algo más estrecho esta última no sería tan grande

# %% [markdown]
# ## 2. Reducción de incertidumbre

# %%
def ci_width(bs, conf):
    a = 1 - conf
    l, u = np.percentile(bs, [100*a/2, 100*(1 - a/2)])
    return u - l

target_reduction = 0.39
orig_conf = 0.937
resumen = []

for var, result in resultados_bootstrap.items():
    boot_dist = np.array(result["bootstrap_distribution"])
    orig_width = ci_width(boot_dist, orig_conf)
    target_width = orig_width * (1 - target_reduction)
    
    confs = np.linspace(0.5, 0.999, 400)
    widths = np.array([ci_width(boot_dist, c) for c in confs])
    
    conf_equiv = confs[np.argmin(np.abs(widths - target_width))]

    resumen.append((var, orig_width, target_width, conf_equiv))
    
    print(f"Variable: {var}")
    print(f"  Ancho original (IC 93.7%)  : {orig_width:.5f}")
    print(f"  Ancho 39% menor (objetivo)  : {target_width:.5f}")
    print(f"  Nivel de confianza equivalente: {conf_equiv*100:.2f}%\n")

var_ref = resumen[0][0]
boot_dist = np.array(resultados_bootstrap[var_ref]["bootstrap_distribution"])
orig_width = resumen[0][1]
target_conf = resumen[0][3]

alpha_equiv = 1 - target_conf
low_new, high_new = np.percentile(boot_dist, [100*alpha_equiv/2, 100*(1-alpha_equiv/2)])
low_orig, high_orig = np.percentile(boot_dist, [100*(1-orig_conf)/2, 100*(1-(1-orig_conf)/2)])

plt.figure(figsize=(9,5))
plt.hist(boot_dist, bins=60, density=True, alpha=0.6, color='lightgreen')
plt.axvline(low_orig, color='red', linestyle='--', label=f'IC {orig_conf*100:.1f}% (original)')
plt.axvline(high_orig, color='red', linestyle='--')
plt.axvline(low_new, color='blue', linestyle='--', label=f'IC {target_conf*100:.1f}% (39% más estrecho)')
plt.axvline(high_new, color='blue', linestyle='--')
plt.title(f"Comparación de ICs modificando el nivel de confianza — {var_ref}")
plt.xlabel("Estadístico bootstrap")
plt.ylabel("Densidad")
plt.legend()
plt.show()

boot_larger = np.random.choice(boot_dist, size=len(boot_dist)*2, replace=True)

low_large, high_large = np.percentile(boot_larger, [100*(1-orig_conf)/2, 100*(1-(1-orig_conf)/2)])
width_large = high_large - low_large

plt.figure(figsize=(9,5))
plt.hist(boot_larger, bins=60, density=True, alpha=0.6, color='lightblue', label='Bootstrap con mayor muestra')
plt.axvline(low_orig, color='red', linestyle='--', label=f'IC {orig_conf*100:.1f}% (original)')
plt.axvline(high_orig, color='red', linestyle='--')
plt.axvline(low_large, color='blue', linestyle='--', label='IC con muestra aumentada')
plt.axvline(high_large, color='blue', linestyle='--')
plt.title(f"Comparación de ICs al aumentar el tamaño muestral — {var_ref}")
plt.xlabel("Estadístico bootstrap")
plt.ylabel("Densidad")
plt.legend()
plt.show()

# %% [markdown]
# La forma de reducir la incertidumbre aumentando el valor de α, disminuyen el IC y lo hace más estrecho, si bien esto provoca que haya menos rango en cuanto a intervalo de confianza, también hay menos incertidumbre. Existe otro método el cual es aumentar la cantidad de datos en la muestra, el cual también reduce la incertidumbre pero aumenta de IC, por lo que se podría considerar como un mejor método

# %% [markdown]
# ## 3. Pruebas de bondad
# El test de Kolmogorov–Smirnov evalúa la bondad de ajuste midiendo la distancia máxima entre la función de distribución acumulada empírica de los datos y la teórica esperada bajo un modelo.
# Si esta distancia es significativa (p < α), se concluye que los datos no siguen la distribución teórica.
#
# - Variable Tasa de desempleo

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from scipy import stats

x = df['Unemployment Rate (%)'].dropna().to_numpy()

plt.hist(x, bins=20, density=True, color='skyblue', edgecolor='k')
plt.title("Histograma de Tasa de Desempleo (%)")
plt.xlabel("Desempleo")
plt.ylabel("Densidad")
plt.show()

print("Media:", np.mean(x))
print("Desv.Est:", np.std(x))
print("Interpretación del gráfico: No hay valores bajo 0, existe una concentración entre 3% y 8% de los datos de los países,") 
print("además existe una cola larga a la derecha donde países alcanzan tasa de desempleo hasta 30% o más. Demostrando una asimetría positiva")

# %%
x = df['Unemployment Rate (%)'].dropna().to_numpy()

shape_l, loc_l, scale_l = stats.lognorm.fit(x, floc=0)
pdf_logn = stats.lognorm.pdf(np.linspace(0, x.max(), 200), shape_l, loc_l, scale_l)

shape_g, loc_g, scale_g = stats.gamma.fit(x, floc=0)
pdf_gamma = stats.gamma.pdf(np.linspace(0, x.max(), 200), shape_g, loc_g, scale_g)

x_plot = np.linspace(0, x.max(), 200)

plt.figure(figsize=(8,5))
plt.hist(x, bins=20, density=True, alpha=0.6, color='lightsteelblue', edgecolor='k', label='Datos reales')
plt.plot(x_plot, pdf_logn, 'r-', lw=2, label=f'Log-Normal (KS=0.1009)')
plt.plot(x_plot, pdf_gamma, 'g--', lw=2, label=f'Gamma (KS=0.1479)')
plt.xlabel('Tasa de Desempleo (%)')
plt.ylabel('Densidad')
plt.title('Comparación de ajustes teóricos: Log-Normal vs Gamma')
plt.legend()
plt.grid(alpha=0.2)
plt.show()

print("Probando con una distribucion de Log-Normal")
x = df['Unemployment Rate (%)'].dropna().to_numpy()

shape, loc, scale = stats.lognorm.fit(x, floc=0)  # forzamos loc=0 (datos >=0)
ks_stat, p_value = stats.kstest(x, 'lognorm', args=(shape, loc, scale))

print(f"KS estadístico = {ks_stat:.4f}, p = {p_value:.4f}")
print(f"Parámetros: shape={shape:.3f}, scale={scale:.3f}")

print("En este caso, la distribución Log-Normal no es adecuada, producto que p < alpha donde p al ser 0 significa una distancia entre la funcion de")
print("distribcion acumulativa empírica y teórica es muy grande, esto se debe a muchos valores cercanos al cero o una cola mas pesada que la esperada")
print("no siendo similar a una Log-normal ideal incluso aunque sea similar al gráfico.")


print(" ")
print("Intentamos con una distribución Gamma")

shape_g, loc_g, scale_g = stats.gamma.fit(x, floc=0)
ks_stat_g, p_value_g = stats.kstest(x, 'gamma', args=(shape_g, loc_g, scale_g))
print(f"Gamma -> KS = {ks_stat_g:.4f}, p = {p_value_g:.4f}")

shape_w, loc_w, scale_w = stats.weibull_min.fit(x, floc=0)
ks_w, p_w = stats.kstest(x, 'weibull_min', args=(shape_w, loc_w, scale_w))
print(f"Weibull -> KS={ks_w:.4f}, p={p_w:.4f}")

a_sn, loc_sn, scale_sn = stats.skewnorm.fit(x)
ks_sn, p_sn = stats.kstest(x, 'skewnorm', args=(a_sn, loc_sn, scale_sn))
print(f"Skew-Normal -> KS={ks_sn:.4f}, p={p_sn:.4f}")

# %% [markdown]
# Se evaluó la bondad de ajuste de la variable tasa de desempleo (%) frente a las distribuciones Log-Normal, Gamma, Weibull y Skew-Normal, mediante la prueba de Kolmogorov–Smirnov con un nivel de significancia de α = 0.05.
# En todos los casos el p-valor resultó 0.0000, por lo que se rechaza la hipótesis nula de ajuste perfecto.
# Sin embargo, la Log-Normal presentó el menor estadístico KS (0.1009) en comparación con las otras distribuciones (Gamma = 0.1479, Weibull = 0.1550, Skew-Normal = 0.1905), indicando que describe de forma más adecuada el comportamiento empírico.
# Dado que los datos presentan asimetría positiva y concentración en valores bajos, se considera que la Log-Normal representa razonablemente la distribución de la tasa de desempleo, aun cuando el test detecte desviaciones significativas debidas al tamaño muestral y a la presencia de colas más pesadas que las esperadas en el modelo teórico.

# %% [markdown]
# - Variable Crecimiento PIB (%anual)

# %%
x = df['GDP Growth (% Annual)'].dropna().to_numpy()

plt.hist(x, bins=25, density=True, color='skyblue', edgecolor='k')
plt.title('Histograma de Crecimiento del PIB (%)')
plt.xlabel('Crecimiento PIB (%)')
plt.ylabel('Densidad')
plt.show()

print("Media:", np.mean(x))
print("Desv.Est:", np.std(x))
print("Mínimo:", np.min(x), "| Máximo:", np.max(x))

# %%
x = df['GDP Growth (% Annual)'].dropna().to_numpy()

# --- Normal ---
mu, sigma = stats.norm.fit(x)
ks_norm, p_norm = stats.kstest(x, 'norm', args=(mu, sigma))

# --- t-Student ---
df_t, loc_t, scale_t = stats.t.fit(x)  # df (grados de libertad), loc, scale
ks_t, p_t = stats.kstest(x, 't', args=(df_t, loc_t, scale_t))


x_plot = np.linspace(x.min(), x.max(), 400)
pdf_norm = stats.norm.pdf(x_plot, mu, sigma)
pdf_t    = stats.t.pdf(x_plot, df_t, loc_t, scale_t)

plt.figure(figsize=(8,5))
plt.hist(x, bins=30, density=True, alpha=0.6, color='lightsteelblue', edgecolor='k', label='Datos')
plt.plot(x_plot, pdf_norm, 'r-',  lw=2, label=f'Normal (KS={ks_norm:.3f})')
plt.plot(x_plot, pdf_t,   'g--', lw=2, label=f't-Student (KS={ks_t:.3f})')
plt.xlabel('Crecimiento PIB (%)'); plt.ylabel('Densidad')
plt.title('Crecimiento del PIB: Normal vs t-Student')
plt.legend(); plt.grid(alpha=0.25); plt.show()

print("Probando distribución Normal y t-Student:")

print(f"Normal   -> KS={ks_norm:.4f}, p={p_norm:.4g}, mu={mu:.3f}, sigma={sigma:.3f}")
print(f"t-Student-> KS={ks_t:.4f}, p={p_t:.4g}, df={df_t:.2f}, loc={loc_t:.3f}, scale={scale_t:.3f}")

# %% [markdown]
# Mediante la prueba de Kolmogorov–Smirnov (α = 0.05) se probaron las distribuciones Normal y t-Student. Observamos que t-Student obtuvo menor KS a comparación de la Normal (0.095 < 0.159) y mayor valor-p por lo que representa mejor los datos, esto se observa con las colas mas anchas del gráfico ya que la Normal no captura bien los datos en presencia de valores extremos o colas pesadas a diferencia de t-Student que logra representar bien las variaciones existentes como años de crisis o expansión económica que presentan los países.

# %% [markdown]
# # 4. Nivel de significancia

# %% [markdown]
# Para las pruebas de bondad de ajuste se empleó un nivel de significancia α = 0.05, que representa la probabilidad máxima de cometer un error tipo I, es decir, rechazar la hipótesis nula siendo verdadera.
# Este valor es estándar en estudios estadísticos, ya que ofrece un equilibrio entre el riesgo de rechazar un modelo adecuado y la capacidad de detectar discrepancias reales.
#
# En los resultados obtenidos, los p-valores de todas las distribuciones fueron inferiores a 0.05, lo que llevó al rechazo de H₀. Sin embargo, el análisis visual mostró que las distribuciones Log-Normal (para desempleo) y t-Student (para crecimiento del PIB) reproducen razonablemente la forma empírica de los datos, por lo que el rechazo estadístico se atribuye más a la alta sensibilidad del test KS frente a ligeras desviaciones y al tamaño muestral que a un mal ajuste real.
#
# Si se utilizara un nivel de significancia más estricto (α = 0.01), las conclusiones serían las mismas; en cambio, un nivel más flexible (α = 0.10) podría aceptar como adecuados los modelos seleccionados.
# Esto demuestra que las conclusiones son robustas frente a cambios moderados en α, y que los modelos elegidos describen de forma coherente los patrones observados.
#
# En resumen, el nivel de significancia empleado es suficiente y apropiado para el tipo de análisis realizado, permitiendo distinguir entre ajustes razonables y desviaciones importantes sin comprometer la validez de las inferencias.

# %% [markdown]
# # 5. Comparación con estadísticos

# %% [markdown]
# # 6. Regresión

# %%
pip install statsmodels

# %%
import statsmodels.api as sm

plt.style.use('default')

print("=" * 80)
print("PREPARACIÓN DE DATOS PARA REGRESIÓN LINEAL")
print("=" * 80)

economic_cols = [
    'Unemployment Rate (%)', 'GDP Growth (% Annual)', 
    'Inflation (CPI %)', 'GDP (Current USD)'
]

print("\nIMPUTACIÓN DE VALORES FALTANTES (Mediana por País):")
print("Columnas disponibles en df:")
print(df.columns.tolist())

print("Columnas esperadas:")
print(economic_cols)

for col in economic_cols:
    if col in df.columns and df[col].isnull().sum() > 0:
        initial_nulls = df[col].isnull().sum()
        df[col] = df.groupby('country_name')[col].transform(
            lambda x: x.fillna(x.median() if not np.isnan(x.median()) else df[col].median())
        )
        final_nulls = df[col].isnull().sum()
        print(f"   - {col}: {initial_nulls} → {final_nulls} nulos")

df.dropna(subset=economic_cols, inplace=True)
print(f"\nFilas totales después de limpieza: {len(df)}")

print("\n\n2. TRANSFORMACIÓN Y SELECCIÓN DE VARIABLES")
print("-" * 40)

df['PIB_log'] = np.log(df['GDP (Current USD)'][df['GDP (Current USD)'] > 0])
df.dropna(subset=['PIB_log'], inplace=True)
print("Variable 'GDP (Current USD)' transformada a 'PIB_log'.")

Y = df['Unemployment Rate (%)']

X_vars = ['GDP Growth (% Annual)', 'Inflation (CPI %)', 'PIB_log']
X = df[X_vars]

print(f"Variable Dependiente (Y): {Y.name}")
print(f"Variables Independientes (X): {', '.join(X_vars)}")
print(f"TIPO DE REGRESIÓN: Regresión Lineal Múltiple (OLS)")

print("\n\n3. IMPLEMENTACIÓN DEL MODELO OLS")
print("-" * 40)

X = sm.add_constant(X)

modelo_ols = sm.OLS(Y, X, hasconst=True).fit()

print("\n**RESUMEN DEL MODELO OLS**")
print("===========================")
print(modelo_ols.summary())

# %% [markdown]
# # 4. Interpretación Crítica del Modelo OLS (Tasa de Desempleo)
#
# ***
# ## 4.1. Validación de la Hipótesis del Proyecto
#
# La hipótesis del proyecto es: **"La tasa de crecimiento del PIB influye mucho más que la inflación y el PIB actual de un país, en su tasa de desempleo."**
#
# Al comparar la magnitud absoluta de los coeficientes, se determina que la hipótesis **se refuta** con los resultados de este modelo.
#
# | Variable | Coeficiente ($\beta$) | P-valor (P>|t|) | Magnitud $|\beta|$ | Conclusión |
# | :--- | :--- | :--- | :--- | :--- |
# | **PIB (log)** | **+0.0600** | **0.042** | **0.0600** | **Mayor impacto y único significativo al 5%.** |
# | **Crecimiento Económico** | -0.0165 | 0.287 | 0.0165 | Menor impacto. No es significativo. |
# | **Inflación (CPI %)** | -0.0052 | 0.325 | 0.0052 | Impacto mínimo y no es significativo. |
#
# **Conclusión Principal:** La variable con la mayor magnitud de impacto es el **PIB (log) ($\beta = 0.0600$)**, no el Crecimiento Económico. Solo esta variable es **estadísticamente significativa** ($p = 0.042$) al nivel de $\alpha=0.05$.
#
# ***
# ## 4.2. Crítica Estadística y Alineación Económica
#
# ### Evaluación del Ajuste (Resultado Negativo)
#
# El modelo presenta un **ajuste extremadamente pobre**:
#
# * **R-squared ($\mathbf{R^2}$):** **0.002** (0.2%). Este es un **resultado negativo** que indica que las variables macroeconómicas seleccionadas explican una porción insignificante de la variabilidad en la Tasa de Desempleo.
# * **Significancia Global:** El **Prob (F-statistic)** es $\mathbf{0.0916}$, lo que implica que el modelo en su totalidad **no es estadísticamente significativo** al nivel de $\alpha=0.05$ (se acepta la hipótesis nula de que todos los $\beta$ son cero).
#
# ### Conexión Teórica y Supuestos (TLC)
#
# 1.  **Coherencia Teórica:** El signo negativo del Crecimiento Económico ($\beta = -0.0165$) es **coherente** con la **Ley de Okun** (mayor crecimiento $\rightarrow$ menor desempleo), aunque su efecto es insignificante. El coeficiente positivo del **PIB (log) ($\beta = +0.0600$)** es, en cambio, **incoherente** con la intuición económica.
# 2.  **Teorema del Límite Central (TLC):**
#     * A pesar de que el EDA previo mostró que las variables **rechazaban el supuesto de normalidad**, el **gran tamaño muestral** ($\mathbf{n=3,472}$) permite invocar el **Teorema del Límite Central (TLC)**.
#     * Esto asegura que la distribución de los estimadores OLS es aproximadamente normal, lo que nos permite confiar en la robustez de los $P$-valores calculados. La principal conclusión es que la **relación lineal es estadísticamente débil**.
